# %%
from proactvl.infer.multi_assistant_inference import MultiAssistantStreamInference
# Out:
# [2026-02-04 06:30:44,048] - [INFO] - [qwen_omni_utils.v2_5.vision_process]: set VIDEO_TOTAL_PIXELS: 90316800

# %% [markdown]
# # Config

# %%
# config
ckpt_path = ''
model_config = None
infer_config = {
    'max_kv_tokens': 16384,
    'assistant_num': 1, # assistant number
    'enable_tts': False,
    'state_threshold': 0.5,
}
generate_config = {
    'do_sample': True,
    'max_new_tokens': 12,
    'temperature': 0.7,
    'top_p': 0.9,
    'repetition_penalty': 1.15,
}
talker_config = None
device_id = 0

# %% [markdown]
# # Load Model

# %%
# load model
stream_infer = MultiAssistantStreamInference(model_config, ckpt_path, infer_config, generate_config, talker_config, f'cuda:{device_id}')
# Out:
# Loading model from checkpoint: oaaoaa/proactvl_base_liveccbase
# Fetching 19 files: 100%|██████████| 19/19 [00:00<00:00, 131287.93it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00, 46.75it/s]
# [OK] Added special tokens to tokenizer.
# Loading checkpoint shards: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]

# %%
# set system prompt 
system_prompt = ('You are a live commentator for a League of Legends (LoL) match. '
'Your role is to independently analyze and narrate the game, delivering insightful, engaging, and natural commentary just like a human expert.')
stream_infer.assistants[0].prime_system_prompt(system_prompt)
# Out:
# [Assistant] setting system prompt of assistant 0 to:
# You are a live commentator for a League of Legends (LoL) match. Your role is to independently analyze and narrate the game, delivering insightful, engaging, and natural commentary just like a human expert.

# %% [markdown]
# # Load Video

# %%
video_path = './asset/sample.mp4'
video_begin = 0
video_end = 30
duration = video_end - video_begin
stream_infer.register_video_reader(video_path, video_begin, video_end)
# video_reader = VideoReader(video_path, video_begin, video_end, stream_infer.model.processor)
# Out:
# Reading video ./asset/sample.mp4 from 0 to 30
# Qwen2VLProcessor
# qwen-vl-utils using torchvision to read video.
# /home/v-weicaiyan/miniconda3/envs/proactvl/lib/python3.10/site-packages/torchvision/io/_video_deprecation_warning.py:5: UserWarning: The video decoding and encoding capabilities of torchvision are deprecated from version 0.22 and will be removed in version 0.24. We recommend that you migrate to TorchCodec, where we'll consolidate the future decoding/encoding capabilities of PyTorch: https://github.com/pytorch/torchcodec
#   warnings.warn(

# %%
overall_cc = {}
for t in range(duration):
    current_second = video_begin + t
    history = ''
    user_query = ''

    assistant_responses, _ = stream_infer.infer_one_chunk(current_second, history=history, user_query=user_query, previous_responses=None)
    if assistant_responses[0].active:
        commentary = assistant_responses[0].commentary.strip()
        overall_cc[current_second] = commentary if assistant_responses is not None else ''
        print(f'[Sec: {current_second}({assistant_responses[0].score})]: {commentary}')
    else:
        print(f'[Sec: {current_second}({assistant_responses[0].score})]: <|SILENCE|>')

print('Final Commentary:', overall_cc)
# Out:
# Assistant 0 history prompt:
# [Sec: 0(0.6015625)]: I think the biggest ...
# Assistant 0 history prompt:
# [Sec: 1(0.96875)]: difference is that ...
# Assistant 0 history prompt:
# [Sec: 2(0.9921875)]: I think you ...
# Assistant 0 history prompt:
# [Sec: 3(0.99609375)]: can really see ...
# Assistant 0 history prompt:
# [Sec: 4(0.9921875)]: that, you know...
# Assistant 0 history prompt:
# [Sec: 5(0.71484375)]: I think this is a ...
# Assistant 0 history prompt:
# [Sec: 6(0.97265625)]: game that, in the ...
# Assistant 0 history prompt:
# [Sec: 7(1.0)]: context of the series, ...
# Assistant 0 history prompt:
# [Sec: 8(0.98046875)]: is going to be ...
# Assistant 0 history prompt:
# [Sec: 9(0.9921875)]: a pretty easy one ...
# Assistant 0 history prompt:
# [Sec: 10(0.99609375)]: for FLY to win.
# Assistant 0 history prompt:
# [Sec: 11(0.640625)]: They're going to be ...
# Assistant 0 history prompt:
# [Sec: 12(0.9765625)]: the favorites, but they ...
# Assistant 0 history prompt:
# [Sec: 13(1.0)]: need to be careful.
# Assistant 0 history prompt:
# [Sec: 14(0.78125)]: You don't want to ...
# Assistant 0 history prompt:
# [Sec: 15(0.9921875)]: underestimate the experience ...
# Assistant 0 history prompt:
# [Sec: 16(0.99609375)]: and the comfort ...
# Assistant 0 history prompt:
# [Sec: 17(1.0)]: that these players ...
# Assistant 0 history prompt:
# [Sec: 18(0.9921875)]: have in this ...
# Assistant 0 history prompt:
# [Sec: 19(0.9921875)]: series, in this ...
# Assistant 0 history prompt:
# [Sec: 20(0.99609375)]: matchup, in this ...
# Assistant 0 history prompt:
# [Sec: 21(0.99609375)]: tournament, and in ...
# Assistant 0 history prompt:
# [Sec: 22(0.99609375)]: this region, right?
# Assistant 0 history prompt:
# [Sec: 23(0.70703125)]: So this is a ...
# Assistant 0 history prompt:
# [Sec: 24(0.98828125)]: team that is going ...
# Assistant 0 history prompt:
# [Sec: 25(1.0)]: to be confident, but ...
# Assistant 0 history prompt:
# [Sec: 26(0.99609375)]: not overconfident, and ...
# Assistant 0 history prompt:
# [Sec: 27(0.98046875)]: we'll see if ...
# Assistant 0 history prompt:
# [Sec: 28(0.98828125)]: they can get ...
# Assistant 0 history prompt:
# [Sec: 29(0.98828125)]: the job done.
# Final Commentary: {0: 'I think the biggest ...', 1: 'difference is that ...', 2: 'I think you ...', 3: 'can really see ...', 4: 'that, you know...', 5: 'I think this is a ...', 6: 'game that, in the ...', 7: 'context of the series, ...', 8: 'is going to be ...', 9: 'a pretty easy one ...', 10: 'for FLY to win.', 11: "They're going to be ...", 12: 'the favorites, but they ...', 13: 'need to be careful.', 14: "You don't want to ...", 15: 'underestimate the experience ...', 16: 'and the comfort ...', 17: 'that these players ...', 18: 'have in this ...', 19: 'series, in this ...', 20: 'matchup, in this ...', 21: 'tournament, and in ...', 22: 'this region, right?', 23: 'So this is a ...', 24: 'team that is going ...', 25: 'to be confident, but ...', 26: 'not overconfident, and ...', 27: "we'll see if ...", 28: 'they can get ...', 29: 'the job done.'}
